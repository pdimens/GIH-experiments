# %% [markdown]
# ---
# title: Linked-Read Metrics
# subtitle: Linked-read metrics relating to barcodes and molecules
# date: "2026-07-17"
# edit_url: null
# ---
#
# **Linked-read type**: haplotagging

# %%
import altair as alt
from harpy.report.html import StatsBox, print_html
from harpy.report.plots import SafeRender
from harpy.report.tables import ITable
from harpy.report.utilities import binned_histogram_polars as binned_histogram
from harpy.report.utilities import nxx_polars as nxx
from harpy.report.utilities import StopExecution
import os
from pathlib import Path
import polars as pl
_ = pl.Config.set_tbl_hide_column_data_types()

# %%
indir = "reports/data/lrstats/"

# %%
# Parameters
indir = "/local/workdir/pd348/mouse/align/reports/data/lrstats"

# %%
def process_input(infile: str) -> dict:
    samplename = os.path.basename(infile).replace(".lrstats.gz", "")
    tb = pl.read_csv(infile, separator='\t', schema_overrides = {'contig': pl.String}).drop(["start", "end"])

    is_valid = pl.col('molecule') != "invalid"
    is_multiplex = is_valid & (pl.col('reads') >= 2)

    multiplex_df = tb.filter(is_multiplex)
    valid_df = tb.filter(is_valid)

    tot_mol = valid_df.height
    tot_valid_reads = valid_df['reads'].sum()
    tot_invalid_reads = tb.filter(~is_valid)['reads'].sum()
    tot_reads = tot_valid_reads + tot_invalid_reads
    if tot_reads == 0:
        return {
            "Sample": samplename,
            "Total Reads": 0,
            "Valid":  0,
            "Linked": 0,
            "Barcodes": 0,
            "Unique Molecules": 0,
            "Molecules/Barcode": 0,
            "Reads/Molecule": 0,
            "Insert Molecule Coverage": 0,
            "Exact Molecule Coverage": 0,
            "N50": 0,
            "N75": 0,
            "N90": 0
        }

    if len(multiplex_df) == 0:
        avg_reads_per_mol = avg_mol_cov = avg_mol_cov_bp = tot_linked_reads = _lens = n50 = n75 = n90 = 0
    else:
        avg_reads_per_mol = round(multiplex_df['reads'].mean() or 0, 1)
        avg_mol_cov = round(multiplex_df['coverage_inserts'].mean() or 0, 2)
        avg_mol_cov_bp = round(multiplex_df['coverage_bp'].mean() or 0, 2)
        tot_linked_reads = multiplex_df['reads'].sum()
        _lens = multiplex_df['length_inferred'].sort(descending=True)

        n50 = nxx(_lens, 50)
        n75 = nxx(_lens, 75)
        n90 = nxx(_lens, 90)

    tot_uniq_bx = tb['molecule'].str.replace(r'-\d+$', '', literal=False).n_unique()

    return {
        "Sample": samplename,
        "Total Reads": tot_reads,
        "Valid": round(tot_valid_reads / tot_reads, 4),
        "Linked": round(tot_linked_reads / tot_reads, 4),
        "Barcodes": tot_uniq_bx,
        "Unique Molecules": tot_mol,
        "Molecules/Barcode": round(tot_mol / tot_uniq_bx, 2),
        "Reads/Molecule": avg_reads_per_mol,
        "Insert Molecule Coverage": avg_mol_cov,
        "Exact Molecule Coverage": avg_mol_cov_bp,
        "N50": n50,
        "N75": n75,
        "N90": n90
    }

# %%
files = [str(i) for i in Path(indir).glob("*.lrstats.gz")]
records = [process_input(i) for i in files]
aggregate_df = (
    pl.DataFrame(records, schema={
        "Sample": pl.String,
        "Total Reads": pl.Int64,
        "Valid": pl.Float64,
        "Linked": pl.Float64,
        "Barcodes": pl.Int64,
        "Unique Molecules": pl.Int64,
        "Molecules/Barcode": pl.Float64,
        "Reads/Molecule": pl.Float64,
        "Insert Molecule Coverage": pl.Float64,
        "Exact Molecule Coverage": pl.Float64,
        "N50": pl.Int64,
        "N75": pl.Int64,
        "N90": pl.Int64
    })
    .fill_nan(0)
    .fill_null(0)
    .sort("Sample")
)

# %% [markdown]
# This report aggregates the barcode-specific information from the alignments
# that were created using `harpy align`. Detailed information for any one sample
# can be found in that sample's individual report. The summary information spotlighted here represents averages across the samples.

# %%
if len(aggregate_df) == 0:
    print_html("All input files were empty, no report to show")
    raise StopExecution

# %%
_n50 = round((aggregate_df['N50'].replace(0, None).mean() or 0) / 1000)
_n75 = round((aggregate_df['N75'].replace(0, None).mean() or 0) / 1000)
_n90 = round((aggregate_df['N90'].replace(0, None).mean() or 0) / 1000)
_bpm = round(aggregate_df['Molecules/Barcode'].replace(0, None).mean() or 0, 2)
_bpmsd = round(aggregate_df['Molecules/Barcode'].replace(0, None).std() or 0, 2)
_linked = round(aggregate_df['Linked'].mean() or 0, 2)
_linkedsd = round(aggregate_df['Linked'].std() or 0, 2)
_rpm = round(aggregate_df['Reads/Molecule'].replace(0, None).mean() or 0, 2)
_rpmsd = round(aggregate_df['Reads/Molecule'].replace(0, None).std() or 0, 2)
_valid = round(aggregate_df['Valid'].replace(0, None).mean() or 0, 2)

(
    StatsBox()
    .add(len(aggregate_df), "Samples")
    .add(_bpm, "Molecules/Barcode", plus_minus=_bpmsd)
    .conditional(_rpm, "Reads/Mol", 2, plus_minus=_rpmsd)
    .conditional(_linked, "Avg Linked", 0.4, as_percent=True)
    .conditional(_valid, "Valid BX", 0.4, as_percent=True)
    .add(_n50, "N50", units = "kb")
    .add(_n75, "N75", units = "kb")
    .add(_n90, "N90", units = "kb")
).render()
# Out:
# <div style="display: flex; gap: 5px;
#             flex-wrap: wrap;"><div style="background-color: transparent ; height: 85px; display: inline-flex; flex-direction: column; white-space: nowrap; align-items: flex-end; justify-content: center; border-radius: 5px; color: #000000; padding: 15px; box-sizing: border-box; text-align: right;"><div style="font-size: 14px; font-weight: 400;margin-bottom: 1px; color: var(--tw-prose-body, #666666);">Samples</div><div style="font-size: 36px; font-weight: 400; color: var(--tw-prose-body, #666666);">6<span style="font-size: 18px; color: var(--tw-prose-body, #666666);"></span></div></div> <div style="background-color: transparent ; height: 85px; display: inline-flex; flex-direction: column; white-space: nowrap; align-items: flex-end; justify-content: center; border-radius: 5px; color: #000000; padding: 15px; box-sizing: border-box; text-align: right;"><div style="font-size: 14px; font-weight: 400;margin-bottom: 1px; color: var(--tw-prose-body, #666666);">Molecules/Barcode</div><div style="font-size: 36px; font-weight: 400; color: var(--tw-prose-body, #666666);">19.66<span style="font-size: 18px; color: var(--tw-prose-body, #666666);">±7.54</span></div></div> <div style="background-color: transparent ; height: 85px; display: inline-flex; flex-direction: column; white-space: nowrap; align-items: flex-end; justify-content: center; border-radius: 5px; color: #000000; padding: 15px; box-sizing: border-box; text-align: right;"><div style="font-size: 14px; font-weight: 400;margin-bottom: 1px; color: var(--tw-prose-body, #666666);">Reads/Mol</div><div style="font-size: 36px; font-weight: 400; color: var(--tw-prose-body, #666666);">5.63<span style="font-size: 18px; color: var(--tw-prose-body, #666666);">±2.08</span></div></div> <div style="background-color: transparent ; height: 85px; display: inline-flex; flex-direction: column; white-space: nowrap; align-items: flex-end; justify-content: center; border-radius: 5px; color: #000000; padding: 15px; box-sizing: border-box; text-align: right;"><div style="font-size: 14px; font-weight: 400;margin-bottom: 1px; color: var(--tw-prose-body, #666666);">Avg Linked</div><div style="font-size: 36px; font-weight: 400; color: var(--tw-prose-body, #666666);">86.0%<span style="font-size: 18px; color: var(--tw-prose-body, #666666);"></span></div></div> <div style="background-color: transparent ; height: 85px; display: inline-flex; flex-direction: column; white-space: nowrap; align-items: flex-end; justify-content: center; border-radius: 5px; color: #000000; padding: 15px; box-sizing: border-box; text-align: right;"><div style="font-size: 14px; font-weight: 400;margin-bottom: 1px; color: var(--tw-prose-body, #666666);">Valid BX</div><div style="font-size: 36px; font-weight: 400; color: var(--tw-prose-body, #666666);">99.0%<span style="font-size: 18px; color: var(--tw-prose-body, #666666);"></span></div></div> <div style="background-color: transparent ; height: 85px; display: inline-flex; flex-direction: column; white-space: nowrap; align-items: flex-end; justify-content: center; border-radius: 5px; color: #000000; padding: 15px; box-sizing: border-box; text-align: right;"><div style="font-size: 14px; font-weight: 400;margin-bottom: 1px; color: var(--tw-prose-body, #666666);">N50</div><div style="font-size: 36px; font-weight: 400; color: var(--tw-prose-body, #666666);">56kb<span style="font-size: 18px; color: var(--tw-prose-body, #666666);"></span></div></div> <div style="background-color: transparent ; height: 85px; display: inline-flex; flex-direction: column; white-space: nowrap; align-items: flex-end; justify-content: center; border-radius: 5px; color: #000000; padding: 15px; box-sizing: border-box; text-align: right;"><div style="font-size: 14px; font-weight: 400;margin-bottom: 1px; color: var(--tw-prose-body, #666666);">N75</div><div style="font-size: 36px; font-weight: 400; color: var(--tw-prose-body, #666666);">36kb<span style="font-size: 18px; color: var(--tw-prose-body, #666666);"></span></div></di ...

# %% [markdown]
# ## Sample Information
#
# The chart below is visual representation of some of the common linked-read  metrics that may help assess the success of sample/library preparation. For more details, see the table beneath the visualization and for even more granularity, you can inspect the report generated for each individual sample.

# %%
hover = alt.selection_point(
    fields=['Sample'],
    on='pointerover',  
    nearest=False,   
    empty=False
)

stroke_color = (
    alt.when(hover).then(alt.value("magenta"))
    .otherwise(alt.value("white"))
)

with SafeRender(aggregate_df):
    (
        alt.Chart(aggregate_df[['Sample', 'Valid', 'Linked', 'Insert Molecule Coverage', 'Exact Molecule Coverage']])
        .transform_fold(['Valid', 'Linked', 'Insert Molecule Coverage', 'Exact Molecule Coverage'])
        .transform_calculate(jitter="(random() - 0.5) * 0.4")
        .mark_point(strokeWidth = 1)
        .encode(
            x=alt.X('value:Q', title='Percent').scale(domain=[0, 1]).axis(format="%"),
            y=alt.Y('jitter:Q', title=None, axis = None).scale(domain=[-0.5, 0.5]),
            color=alt.Color('key:N', legend = None),
            shape='key:N',
            stroke=stroke_color,
            tooltip=[
                'Sample:N',
                alt.Tooltip('key:N', title="Metric"),
                alt.Tooltip('value:Q', title="", format='.2%')
            ]
        )
        .add_params(hover)
        .properties(width=620, height=65)
        .facet(
            row=alt.Row('key:N', title=None, header=alt.Header(labelOrient='left', labelAngle = 0, labelAlign='left'))
        )
        .resolve_scale(y='independent')
        .properties(
            title=alt.Title('Per-Sample Metrics'),
            usermeta={'embedOptions': {'downloadFileName': 'alignments.per.sample'}}
        )
        .configure_legend(orient="top")
        .configure_view(stroke="#888888", strokeWidth=0.7)
    ).display()
# Out:
# alt.FacetChart(...)

# %% [markdown]
# This table [^1] is an aggregation of data for each sample based on their `*.lrstats.gz` file.
# Every column after `Barcodes` ignores singletons in its calculations.
#
# [^1]:
#     | Column | Description |
#     |:-------|:------------|
#     | `Sample` | name of the sample |
#     | `Total Reads`| total number of alignments |
#     | `Valid` | proportion of valid barcoded alignments |
#     | `Unique Molecules` | the unique DNA molecules as inferred from linked-read barcodes |
#     | `Linked` | molecules composed of two or more single/paired-end sequences, in other words, molecules with linked-read information |
#     | `Barcodes` | number of unique barcodes, which may differ from unique molecules after deconvolution |
#     | `Molecules/Barcode` | molecule-to-barcode ratio, which helps benchmark deconvolution performance, if performed |
#     | `Reads/Molecule` | average number of reads per unique molecule |
#     | `Insert Molecule Coverage` | average percent of a molecule that is covered by a read, where coverage includes unsequenced gaps between linked reads |
#     | `Exact Molecule Coverage` | average percent molecule coverage, where coverage only includes sequences and not the gaps between linked reads |
#     | `N50` | N50 of inferred molecules |
#     | `N75` | N75 of inferred molecules |
#     | `N90` | N90 of inferred molecules |

# %%
ITable(aggregate_df, "alignment.lr.csv", fixedcols=2).render()
# Out:
#         <style>
#             .ag-theme-quartz, .ag-theme-quartz-dark {
#                 --ag-font-family: sans-serif;
#             }
#         </style>
#
#         <button
#             onclick="(function(){ var g = window.aggrid_3d896ca8; if(g) g.exportDataAsCsv({suppressQuotes: true, fileName: 'alignment.lr.csv'}); })()"
#             style="margin-bottom: 8px; padding: 4px 12px; cursor: pointer;"
#         >
#             ⤓ Download CSV
#         </button>
#
#         <div id="grid-3d896ca8" class="ag-theme-quartz" style="width: 100%; overflow-x: auto"></div>
#
#         <script>
#         (async function () {
#
#                     /* ── dynamic loader: awaitable, idempotent ── */
#             await new Promise((resolve, reject) => {
#                 if (typeof agGrid !== "undefined") { resolve(); return; }
#                 const s = document.createElement("script");
#                 s.src = "https://cdn.jsdelivr.net/npm/ag-grid-community/dist/ag-grid-community.min.js";
#                 s.onload = resolve;
#                 s.onerror = reject;
#                 document.head.appendChild(s);
#             });
#
#
#                 // ---------- decompress columnar gzip payload ----------
#                 const _b64 = "...";
#                 const _binary = Uint8Array.from(atob(_b64), c => c.charCodeAt(0));
#                 const _ds = new DecompressionStream("gzip");
#                 const _writer = _ds.writable.getWriter();
#                 _writer.write(_binary);
#                 _writer.close();
#                 const _buf = await new Response(_ds.readable).arrayBuffer();
#                 const _pkg = JSON.parse(new TextDecoder().decode(_buf));
#
#                 // Reconstruct row-oriented array from columnar structure
#                 const _cols = _pkg.cols;
#                 const _data = _pkg.data;
#                 const rowData = _data[_cols[0]].map((_, i) =>
#                     Object.fromEntries(_cols.map(c => [c, _data[c][i]]))
#                 );
#                 // ------------------------------------------------------
#
#
#             const columnDefs = [{"field": "Sample", "pinned": "left"}, {"field": "Total Reads", "pinned": "left"}, {"field": "Valid"}, {"field": "Linked"}, {"field": "Barcodes"}, {"field": "Unique Molecules"}, {"field": "Molecules/Barcode"}, {"field": "Reads/Molecule"}, {"field": "Insert Molecule Coverage"}, {"field": "Exact Molecule Coverage"}, {"field": "N50"}, {"field": "N75"}, {"field": "N90"}];
#
#             const gridOptions = {
#                 columnDefs: columnDefs,
#                 rowData: rowData,
#                 defaultColDef: {
#                     sortable: true,
#                     filter: true,
#                     resizable: true,
#                 },
#                 autoSizeStrategy: {
#                     type: "fitCellContents",
#                     defaultMaxWidth: 170,
#                     defaultMinWidth: 90,
#                 },
#                 domLayout: "autoHeight",
#                 animateRows: false,
#                 pagination: true,
#                 paginationPageSize: 20,
#                 rowHeight: 28,
#                 headerHeight: 32,
#             };
#
#             const container = document.getElementById("grid-3d896ca8");
#
#             function syncTheme() {
#                 container.setAttribute(
#                     "data-ag-theme-mode",
#                     document.documentElement.classList.contains("dark") ? "dark-blue" : "light"
#                 );
#             }
#
#             requestAnimationFrame(() => {
#                 requestAnimationFrame(() => {
#                     syncTheme();
#                     window.aggrid_3d896ca8 = agGrid.createGrid(container, gridOptions);
#                     new MutationObserver(syncTheme).observe(
#                         document.documentElement,
#                         { attributes: true, attributeFilter: ["class"] }
#                     );
#                 });
#             });
#
#         })();
#         </script>

# %% [markdown]
# ## Library Performance
# ### NX metrics
#
# The **NX** metrics (e.g. **N50**) tend to be useful for understanding centrality for molecule length in genomic contexts.
# With your linked-read sequences aligned to a reference genome, you can make inferences about the lengths of the original molecules from which linked-read fragments were derived. These are the distributions of three common NX metrics (N50, N75, N90) across all samples are given below.

# %%
selection = alt.selection_point(fields=['Nxx'], bind='legend')

with SafeRender(aggregate_df):
    (
        alt.Chart(aggregate_df[['Sample', 'N50', 'N75', 'N90']])
        .transform_fold(
            ['N50', 'N75', 'N90'],
            as_=['Nxx', 'value']
        )
        .transform_density(
            'value',
            groupby=['Nxx'],
            as_=['value', 'density']
        )
        .mark_area(interpolate = "basis")
        .encode(
            x=alt.X('value:Q', bin = "binned").axis(title='Length (kb)', labelExpr='datum.value / 1000'),
            y=alt.Y('density:Q', title='Density').axis(labels = False),
            color=alt.Color('Nxx:N', title='Metric').scale(domain = ['N50','N75','N90'])
        )
        .transform_filter(selection)
        .add_params(selection)
        .configure_legend(orient = "top")
        .properties(
            title=alt.Title('Nxx Values', subtitle = 'Values derived using non-singleton molecules'),
            usermeta={'embedOptions': {'downloadFileName': f'alignments.nxx'}}
        )
    ).display()
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Reads per molecule
# This distribution shows the average number of reads per inferred molecule across your samples.

# %%
_hist = binned_histogram(aggregate_df['Reads/Molecule'], 0.25, True)
with SafeRender(_hist):
    (
        alt.Chart(_hist)
        .mark_area(interpolate = "monotone")
        .encode(
            x=alt.X('interval:O')
                .axis(title='Reads Per Molecule', tickMinStep=0.5, labelAngle=-40)
                .scale(domainMin=0,padding=0),
            y=alt.Y('proportion:Q', title='Percent of Samples').axis(format = '%'),
            tooltip = [
                alt.Tooltip('interval', title = "Reads Per Molecule"),
                alt.Tooltip('proportion', title = "Percent of Samples").format('.1%')
            ]
        )
        .properties(
            title=alt.Title('Reads Per Molecule', subtitle = 'Values derived using non-singleton molecules'),
            usermeta={'embedOptions': {'downloadFileName': f'alignments.readspermol'}}
        )
    ).display()
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Valid barcodes
# This is a distribution of what percent of total alignments each sample had valid barcodes[^3]:
#
# [^3]:
#     Valid barcodes with respect to the conventions of a given linked-read chemistry:
#
#     **haplotagging**: `AxxCxxBxxDxx` where `xx` is not `00`
#
#     **stLFR**: `X_Y_Z` where `X`, `Y`, or `Z` is not `0`
#
#     **TELLseq**: there is no `N` nucleotide

# %%
_hist = binned_histogram(aggregate_df['Valid'], 0.1, True, 1)
with SafeRender(_hist):
    (
        alt.Chart(_hist)
        .mark_area(interpolate = "monotone")
        .transform_filter(alt.datum.bin <= 1)
        .encode(
            x=alt.X('interval:O')
                .axis(title='Proportion Valid Barcodes', labelAngle=-40)
                .scale(domainMin=0,padding=0),
            y=alt.Y('proportion:Q', title='Percent of Samples').axis(format = '%').scale(domain=[0,1]),
            tooltip = [
                alt.Tooltip('interval', title = "Proportion Valid Barcodes"),
                alt.Tooltip('proportion', title = "Percent of Samples").format('.1%')
            ]
        )
        .properties(
                title=alt.Title('Proportion Valid Barcodes'),
            usermeta={'embedOptions': {'downloadFileName': f'alignments.percent.valid'}}
        )
    ).display()
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Total reads vs
# This scatterplot is a diagnostic that shows the relationship between the proportion of total reads compared to _something_. Each point is a sample and is colored by the value of the variable you select.

# %%
_ycols = ["Valid", "Unique Molecules", "Linked", "Barcodes", "Molecules/Barcode", "Reads/Molecule"]
dropdowny = alt.binding_select(
    options= _ycols,
    labels=[f" {i}  " for i in _ycols],
    name='Y Axis: '
)
ycol_param = alt.param(value='Linked', bind=dropdowny)

with SafeRender(aggregate_df):
    (
        alt.Chart(aggregate_df[['Sample', 'Valid', 'Total Reads', "Unique Molecules", "Linked", "Barcodes", "Molecules/Barcode", "Reads/Molecule"]])
        .mark_point(stroke = "white", strokeWidth = 1)
        .add_params(ycol_param)
        .transform_calculate(Selected=f'datum[{ycol_param.name}]')
        .encode(
            y=alt.Y('Selected:Q', title = ''),
            x='Total Reads:Q',
            color=alt.Color('Selected:Q').scale(scheme='turbo', reverse = True),
            tooltip = ['Sample', 'Selected:Q', 'Total Reads:Q']
        )
        .properties(
            title=alt.Title('Proportion against Total Reads'),
            usermeta={
                'embedOptions': {'downloadFileName': f'alignments.percent.linked'},
                'padding': {'left': 80, 'right': 20, 'top': 10, 'bottom': 10}
            }
        )
    ).display()
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Supporting Info
#
# :::{dropdown} NX values
# `NX` is the length of the shortest molecule that when you sum the lengths of every molecule larger than it, represents at least **X%** of the total molecules by length. For example, `N50` would be the molecule length at which the sum of all the molecule lengths larger than it would
# represent **50%** of the total molecules by length (sort of like a cumulative median).
#
# As an example, imagine we had molecules with lengths [4, 3, 2, 1], making up a total length of 10. The `N50`
# would be the first number (starting from the biggest) that sums up to at least 5 (50% of 10), which is `3`, because `4` + `3` = 7. The `N90` would be the first number that sums up to at least 9 (90% of 10), which is `2` because `4` + `3` + `2` = 9.
# :::
#
# :::{dropdown} Understanding inferred molecule lengths
# Harpy uses the highest and lowest mapping positions of a read cluster sharing the same barcode (incorporating distance-based deconvolution thresholds, if configured to do so) to infer the original molecule length. Given that it's mostly impossible to understand how much of a source molecule the mapped reads actually covered, it would be more appropriate to think of the inferred molecule lengths (and NX measures) to be more like _"at least this long"_, since the reads likely did not originate from the ends of the source DNA molecule. The absolute length of the source DNA molecule would be a more useful diagnostic in troubleshooting/modifying the actual linked-read chemistry, whereas the the inferred molecule length describes what length of it is actually represented in the sequences and thus more useful in downstream/analytical contexts.
# :::
